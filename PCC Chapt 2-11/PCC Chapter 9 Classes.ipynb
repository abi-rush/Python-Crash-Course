# %%
# Object oriented programming is one of the most effective 
# approaches to wrting software
# in object oriented programming you write classes
# classes represent real-world things and situations
# you create objects based on these classes
# when you write a class you define the general behavior 
# that a whole category of objects can have


# when you create individual objects from the class, 
# each object is automatically equipped with the general behavior;
# you can then give each object whatever unique traits you desire

# making an object from a class is called instantiation
# and you work with instances of a class

# %%
## CREATING AND USING A CLASS

# You can model almost anything using classes.
# let's start by wrting a simple class, Dog, 
# not one dog in particular, but any dog.
# What do we know about most pet dogs?
# Well, they all have a name and age.
# tey sit and roll over.
# these characteristics will go in our class
# since they are common to most dogs
# this class will tell python how to make an object representign a dog
# after our class is written, we'll use it to make
# individual instances, each of which represents one specific dog

# %%
## CREATING THE DOG CLASS

# each instance created from the Dog class will store a name and an age
# and will give each dong the ability to sit() and roll_over()
# Capitalized names refer to classes (conventionally)

class Dog():
    """A simple attempt to model a dog"""
    def __init__(self, name, age):
        """Initialize name an dage attributes."""
        self.name = name
        self.age = age
        
    def sit(self):
        """Simulate a dog sitting in response to a command"""
        print(self.name.title() + " is now sitting.")
        
    def roll_over(self):
        """Simulate rolling over in response to a command."""
        print(self.name.title() + " rolled over!")

# %%
## THE __init__() METHOD

# a function that's part of a class is a method
# everything we learned about functions applies to methods as well
# the only practical difference for now is the way we'll call methods

# this methodruns automatically whenever we create a new instance based 
# on the Dog class

# this method has to leading _ and two trailing _
# this convention helps python's default methods from confliction with 
# the methods you write


# we define the __init()__() method to have three parameters:
# self, name, and age

# the self parameter is required and must come first before the other
# parameters. It must be included in teh definition becuase when Python 
# calls this __init()__ method later (to create an instance of Dog),
# the method call will automatically pass the self argument

# Every method call associated with a class automatically passes self, 
# which is a reference to teh instance itself; it gives the individual instance 
# access to the attributes adn methods in the class

# when we make an instance of Dog, Python will call the __init__() 
# method from the Dog class.
#We'll pass Dog() a name and an age as arguments; self is passed automatically
# so we don't need to pass it. 
# whenever we want to make an instance from the Dog class, we'll provide
# values for only the last two parameters, name and age
 
# any variabe prefied with self is available to every method in the class
# we'll also be able to access these variable through any instance created
# from the class.
# self.name = name takes the value stored int he parameter name
# and stores it in teh variable name, which is then attached to the 
# instance being created

# the same process happens with self.age = age. Variables that are accessible
# through instances like this are alled attributes.


# two other methods are defined: sit() and roll_over()
# bc these methods don't need additional info like name and age
# we jsut define them to have one parameter, self.
# The instances we create later will have access to these methods
# In other words, they'll be able to sit and roll over. For now, sit()
# and roll_over don't do much.
# They simply print a message saying the dog is sitting or rolling over.
# But the concept can be extended to realistic situations: if this class were 
# part of an actual computer game, these methods would contain code to make an animated 
# dog sit and roll over. 
# If this class was written to control a robot, these methods would direct movements that
# cause a dog robot to sit and roll over

# %%
## MAKING AN INSTANCE FROM A CLASS

# think of a class as a set of instrucions for making an instance
# the class Dog is a set of insturctions that tells Python how to 
# make individual instances representign specific dogs.

# Let's make an instance representing a specific Dog


## lower case my_dog refers to an instnace of a class uppercase Dog
my_dog = Dog('willie', 6)

print("my dog's name is " + my_dog.name.title() + ".")
print("My dog is " + str(my_dog.age) + " years old")
# Out:
# my dog's name is Willie.
# My dog is 6 years old

# %%
## ACCESSING ATTRIBUTES

# to access the attributes of an instance, you use dot notation
# access the dog's name with my_dog.name
# this syntax demonstrates how Python finds an attribut's value
# Here Python looks at the instance my_dog
# and then finds the attribute name associated with my_dog
# this is the same attribute referred to as self.name in the
# class Dog.

# %%
## CALLING METHODS

my_dog.sit() #looks for method sit in class Dog and runs that code
my_dog.roll_over() # looks for method role_over in the same way

# this syntax is useful as we can easily infer a block of code we've
# never seen before
# Out:
# Willie is now sitting.
# Willie rolled over!

# %%
## CREATING MULTIPLE INSTANCES

# crating another dog

your_dog = Dog('lucy', 3)

print("Your dog's name is: " + your_dog.name.title())
print("Your dog is " + str(your_dog.age) + " years old")
your_dog.sit()


print("your dog's name is " + your_dog.name.title() + " but my dog's name is " + 
     my_dog.name.title())



# you can make as many instances as long as you give each a unique variable name
# or it occupies a unique spot in a list or dictionary
# Out:
# Your dog's name is: Lucy
# Your dog is 3 years old
# Lucy is now sitting.
# your dog's name is Lucy but my dog's name is Willie

# %%
## TRY IT YOURSELF 9.1 - 9.3

class Restaurant():
    """Restaurant info"""
    def __init__(self, restaurant_name, cuisine_type):
        self.restaurant_name = restaurant_name
        self.cuisine_type = cuisine_type
        
    def describe_restaurant(self):
        """prints name and food type"""
        print("\nThe restuarant name is: " + self.restaurant_name.title())
        print("The cuisine is: " + self.cuisine_type.title())
        
    def open_restaurant(self):
        """prints whether the restaurant is open or not"""
        print("The restaurant is open, yay!")

# %%
dominos = Restaurant('dominos pizza', 'italian')

print("The restuarant " + dominos.restaurant_name.title() + " serves " + 
     dominos.cuisine_type + " food ")

Restaurant.open_restaurant(dominos)



##########################################################

tb = Restaurant('Taco Bell', 'mexican')
Restaurant.describe_restaurant(tb)

rest_2 = Restaurant("Chili's", 'tex mex?')
Restaurant.describe_restaurant(rest_2)




#########################################################

class User():
    """Describe user profiles"""
    def __init__(self, first_name, last_name):
        User.first_name = first_name
        User.last_name = last_name
        
    def describe_user(self):
        """Prints user's names"""
        print("\nFirst name: " + User.first_name + 
             "\nLast name: " + User.last_name)
        
    def greet_user(self):
        """Greets the user"""
        print("Hi there " + User.first_name + " " + User.last_name)
        
ar = User('abigail', 'rushworth')

User.describe_user(ar)
User.greet_user(ar)


lr = User('lola', 'rushworth')

User.describe_user(lr)
User.greet_user(lr)
# Out:
# The restuarant Dominos Pizza serves italian food
# The restaurant is open, yay!
#
# The restuarant name is: Taco Bell
# The cuisine is: Mexican
#
# The restuarant name is: Chili'S
# The cuisine is: Tex Mex?
#
# First name: abigail
# Last name: rushworth
# Hi there abigail rushworth
#
# First name: lola
# Last name: rushworth
# Hi there lola rushworth

# %%
## WORKING WITH CLASSES AND INSTANCES

# You can use classes to represent many real-world situations
# you can modify the attirbuts associated with a particular instance
# either directly or right methods that update attributes in specific ways

# %%
## THE CAR CLASS

class Car():
    """A simple attempt to represent a car"""
    
    def __init__(self, make, model, year):
        """Initialize attributes"""
        self.make = make
        self.model = model
        self.year = year
        
    def get_descriptive_name(self):
        """Return a neatly formatted descriptive name"""
        long_name = str(self.year) + ' ' + self.make + ' ' + self.model
        return long_name.title()
    
    
my_new_car = Car('audi', 'a4', '2016')
print(my_new_car.get_descriptive_name())
# Out:
# 2016 Audi A4

# %%
## SETTING A DEFAULT VALUE FOR AN ATTRIBUTE

# every attribute in a class needs an initial value, 
# even if that value is 0 or an empty string
# it makes sense to specify this value in the body of 
# the __init__() method
# if you do this for an attribute, you don't have to 
# incldue a parameter for that attribute

# add an attribtue called odometer_reading that always 
# starts with 0 also add read_odometer()


class Car():
    """A simple attempt to represent a car"""
    
    def __init__(self, make, model, year):
        """Initialize attributes"""
        self.make = make
        self.model = model
        self.year = year
        self.odometer_reading = 0
        
    def get_descriptive_name(self):
        """Return a neatly formatted descriptive name"""
        long_name = str(self.year) + ' ' + self.make + ' ' + self.model
        return long_name.title() 
    
    def read_odometer(self):
        """Print a satement showing milage"""
        print("Milage on this car is: " + str(self.odometer_reading))
        

my_new_car = Car('audi', 'a4', '2016')
print(my_new_car.get_descriptive_name())        
my_new_car.read_odometer()
# Out:
# 2016 Audi A4
# Milage on this car is: 0

# %%
## MODIFYING ATTRIBUTE VALUES

# not many cars are sold with exactly 0 miles
# you can change the value directly though an instance
# set the value through a method, or increment the value
# (add a certain amount to it) through a method

# %%
## MODIFYING AN ATTRIBUTE'S VALUE DIRECTLY

# Simplist way, access attribute directly through an instance

# set odometer to 23 directly

class Car():
    """A simple attempt to represent a car"""
    
    def __init__(self, make, model, year):
        """Initialize attributes"""
        self.make = make
        self.model = model
        self.year = year
        self.odometer_reading = 0 # note name convention not read_odometer
        
    def get_descriptive_name(self):
        """Return a neatly formatted descriptive name"""
        long_name = str(self.year) + ' ' + self.make + ' ' + self.model
        return long_name.title() 
    
    def read_odometer(self):
        """Print a satement showing milage"""
        print("Milage on this car is: " + str(self.odometer_reading))
        

my_new_car = Car('audi', 'a4', '2016')
print(my_new_car.get_descriptive_name()) 


my_new_car.odometer_reading = 23
my_new_car.read_odometer()
# Out:
# 2016 Audi A4
# Milage on this car is: 23

# %%
## MODIFYING AN ATTRIBUTE'S VALUE THROUGH A METHOD

# sometimes you'll want to write a method that updates
# the value for you 

# instead of accessing attribute directly, you pass the new
# value to a method that updates internaly

class Car():
    """A simple attempt to represent a car"""
    
    def __init__(self, make, model, year):
        """Initialize attributes"""
        self.make = make
        self.model = model
        self.year = year
        self.odometer_reading = 0 # note name convention not read_odometer
        
    def get_descriptive_name(self):
        """Return a neatly formatted descriptive name"""
        long_name = str(self.year) + ' ' + self.make + ' ' + self.model
        return long_name.title() 
    
    def read_odometer(self):
        """Print a satement showing milage"""
        print("Mileage on this car is: " + str(self.odometer_reading))
        
        
    def update_odometer(self, mileage):
        """Set the odometer reading to the given value"""
        self.odometer_reading = mileage
        
        if mileage >= self.odometer_reading:
            self.odometer_reading = mileage
        else:
            print("You can't roll back an odometer!")
        
my_new_car = Car('audi', 'a4', '2016')
print(my_new_car.get_descriptive_name()) 

my_new_car.update_odometer(32)
my_new_car.read_odometer()
# Out:
# 2016 Audi A4
# Mileage on this car is: 32

# %%
my_new_car.update_odometer(12)
my_new_car.read_odometer()
# Out:
# Mileage on this car is: 12

# %%
my_new_car.odometer_reading = 2

# %%
my_new_car.read_odometer()
# Out:
# Mileage on this car is: 2

# %%
## idk why but i can't get that check to work???
# it lets me reduce it? i think unless im updating wrong
# anyway moving on i guess

# %%
## INCREMENTING AN ATTRIBUTE'S VALUE THORUGH A METHOD

#  sometimes you wnat to increment value by certain amount
class Car():
    """A simple attempt to represent a car"""
    
    def __init__(self, make, model, year):
        """Initialize attributes"""
        self.make = make
        self.model = model
        self.year = year
        self.odometer_reading = 0 # note name convention not read_odometer
        
    def get_descriptive_name(self):
        """Return a neatly formatted descriptive name"""
        long_name = str(self.year) + ' ' + self.make + ' ' + self.model
        return long_name.title() 
    
    def read_odometer(self):
        """Print a satement showing milage"""
        print("Mileage on this car is: " + str(self.odometer_reading))
        
        
    def update_odometer(self, mileage):
        """Set the odometer reading to the given value"""
        self.odometer_reading = mileage
        
        if mileage >= self.odometer_reading:
            self.odometer_reading = mileage
        else:
            print("You can't roll back an odometer!")
            
            
    def increment_odometer(self, miles):
        """Add the given amount to the odometer reading"""
        self.odometer_reading += miles
        
        
my_used_car = Car('sube', 'outback', 2013)
print(my_used_car.get_descriptive_name())

my_used_car.update_odometer(23500)
my_used_car.read_odometer()


my_used_car.increment_odometer(100)
my_used_car.read_odometer()


# you could modify this method to reject negative incrememtns so you can't
# use this function to roll back odometer
# Out:
# 2013 Sube Outback
# Mileage on this car is: 23500
# Mileage on this car is: 23600

# %%
## TRY IT YOURSLEF

class Restaurant():
    """Restaurant info"""
    def __init__(self, restaurant_name, cuisine_type):
        self.restaurant_name = restaurant_name
        self.cuisine_type = cuisine_type
        self.number_served = 0
        
    def describe_restaurant(self):
        """prints name and food type"""
        print("\nThe restuarant name is: " + self.restaurant_name.title())
        print("The cuisine is: " + self.cuisine_type.title())
        print("The restaurant has served: " + str(self.number_served))
        
    def open_restaurant(self):
        """prints whether the restaurant is open or not"""
        print("The restaurant is open, yay!")
        
    def set_number_served(self, customers):
        """set number of customers served"""
        self.number_served += customers
        
        
diMarias = Restaurant('diMarias', 'italian')
diMarias.describe_restaurant()

diMarias.set_number_served(5)
diMarias.describe_restaurant()



###########################################################

class User():
    """Describe user profiles"""
    def __init__(self, first_name, last_name, username, email, location):
        User.first_name = first_name
        User.last_name = last_name
        self.username = username
        self.email = email
        self.location = location.title()
        self.login_attempts = 0
        
    def describe_user(self):
        """Prints user's names"""
        print("\nFirst name: " + User.first_name + 
             "\nLast name: " + User.last_name)
        print("Username: " + self.username)
        print("email: " + self.email)
        print("location: " + self.location)
        
    def greet_user(self):
        """Greets the user"""
        print("Hi there " + User.first_name + " " + User.last_name)
        
    def increment_login_attempts(self):
        """Tracks login attempts"""
        self.login_attempts += 1 
        print("Login attempts: " + str(self.login_attempts))
    
    def reset_login_attempts(self):
        """Resets login attmepts to 0"""
        self.login_attempts = 0
        print("Login attemtps reset to:" + str(self.login_attempts))
        
ar = User('abigail', 'rushworth', 'arush', 'arush@gmail', 'charlotte')

ar.describe_user()
print("\n")
ar.increment_login_attempts()
ar.increment_login_attempts()
ar.increment_login_attempts()
ar.reset_login_attempts()
# Out:
# The restuarant name is: Dimarias
# The cuisine is: Italian
# The restaurant has served: 0
#
# The restuarant name is: Dimarias
# The cuisine is: Italian
# The restaurant has served: 5
#
# First name: abigail
# Last name: rushworth
# Username: arush
# email: arush@gmail
# location: Charlotte
#
#
# Login attempts: 1
# Login attempts: 2
# Login attempts: 3
# Login attemtps reset to:0

# %%
## INHERITANCE

# you don't have to start from scratch when writting a class
# if your class is a specialized version of a class you already wrote
# you can use inheritance
# when one class inherits from another, it automatically inherits from
# another, it takes on all the attributes adn methods of the first class
# the original class is the parent class and the new on is the child class
# the child inherits everything from the parents but is free to 
# to have new attributes and methods too

# %%
## THE __init__() METHOD FOR A CHILD CLASS

# Imagine the following is in a .py file

class Car():
    """A simple attempt to represent a car"""
    
    def __init__(self, make, model, year):
        """Initialize attributes"""
        self.make = make
        self.model = model
        self.year = year
        self.odometer_reading = 0 # note name convention not read_odometer
        
    def get_descriptive_name(self):
        """Return a neatly formatted descriptive name"""
        long_name = str(self.year) + ' ' + self.make + ' ' + self.model
        return long_name.title() 
    
    def read_odometer(self):
        """Print a satement showing milage"""
        print("Mileage on this car is: " + str(self.odometer_reading))
        
        
    def update_odometer(self, mileage):
        """Set the odometer reading to the given value"""
        self.odometer_reading = mileage
        
        if mileage >= self.odometer_reading:
            self.odometer_reading = mileage
        else:
            print("You can't roll back an odometer!")
            
            
    def increment_odometer(self, miles):
        """Add the given amount to the odometer reading"""
        self.odometer_reading += miles
        
        
## child class
class ElectricCar(Car):
    """Represent aspects of a car, specific to electric vehicals"""
    def __init__(self, make, model, year):
        """Initialize attributes of the parant calss."""
        super().__init__(make, model, year)
        
        
my_tesla = ElectricCar('tesla', 'model s', 2016)
print(my_tesla.get_descriptive_name())
# Out:
# 2016 Tesla Model S

# %%
## DEFINING ATTRIBUTES ADN METHODS FOR THE CHILD CLASS

class Car():
    """A simple attempt to represent a car"""
    
    def __init__(self, make, model, year):
        """Initialize attributes"""
        self.make = make
        self.model = model
        self.year = year
        self.odometer_reading = 0 # note name convention not read_odometer
        
    def get_descriptive_name(self):
        """Return a neatly formatted descriptive name"""
        long_name = str(self.year) + ' ' + self.make + ' ' + self.model
        return long_name.title() 
    
    def read_odometer(self):
        """Print a satement showing milage"""
        print("Mileage on this car is: " + str(self.odometer_reading))
        
        
    def update_odometer(self, mileage):
        """Set the odometer reading to the given value"""
        self.odometer_reading = mileage
        
        if mileage >= self.odometer_reading:
            self.odometer_reading = mileage
        else:
            print("You can't roll back an odometer!")
            
            
    def increment_odometer(self, miles):
        """Add the given amount to the odometer reading"""
        self.odometer_reading += miles
        

## child class
class ElectricCar(Car):
    """Represent aspects of a car, specific to electric vehicals"""
    def __init__(self, make, model, year):
        """
        Initialize attributes of the parant calss.
        Then initalize attributes specific to an electric car
        """
        super().__init__(make, model, year)
        self.battery_size = 70
        
    def describe_battery(self):
        """Print a statement describing the battery size."""
        print("This car has a " + str(self.battery_size) + "-kWh battery.")
        
my_tesla = ElectricCar('tesla', 'model s', 2016)
print(my_tesla.get_descriptive_name())      
my_tesla.describe_battery()
# Out:
# 2016 Tesla Model S
# This car has a 70-kWh battery.

# %%
## OVERRIDING METHODS FROM THE PARENT CLASS

# you can override methods from the parent class 
# do this by defining a method in child class with same 
# name as the method you want to override in parent calss

# lets say Car had a method for fill_gas_tank()
# you would override it like this

def ElectricCar(Car):
    --snip--
    
    
    def fill_gas_tank():
        """Electric cars don't have gas tanks."""
        print("This car doesn't have a gas tank")
# Out:
#   File "<ipython-input-26-5dd16bebab6a>", line 11
#     --snip--
#             ^
# SyntaxError: invalid syntax

# %%
## INSTANCES AS ATTRIBUTES

# when modeling something in teh real world in code, you may find that you're
# adding more and more detail to a class
# you'll find that you have a growing list of attributes and methods and that your 
# files are becomming lengthy. In these situations you might write part of a class
# as a seperate class of its own

# ie we could move everything to do with an Electric Car's battery 
# to it's own class

class Car():
    --snip--
    
    
class Battery():
    """A simple attempt to model a battery for an electric car."""
    
    def __init__(self, battery_size = 70):
        """Initialize the battery's attributes."""
        self.battery_size = battery_size
    
    def describe_battery(self):
        """Print a statement describing the battery size"""
        print("This car has a " + str(self.battery_size) + "-kWh battery.")
        
class ElectricCar(Car):
    """Represent aspects of a car, specific to electric vehicals"""
    
    def __init__(self, make, model, year):
        """
        Initialize attributes of the parent class
        Then initialize attributes specific to an electric car
        """
        
        super().__init__(make, model, year)
        self.battery = Battery()
        
        
        
my_tesla = ElectricCar('tesla', 'model s', '2016')
print(my_tesla.get_descriptive_name())
my_tesla.battery.describe_battery()
# Out:
#   File "<ipython-input-27-8e260c7b997f>", line 13
#     --snip--
#             ^
# SyntaxError: invalid syntax

# %%
# you could add more to battery:

class Car():
    --snip--
    
class Battery():
    ---snip--
    
    def get_range(self):
        """Print a statement about the range this battery provides"""
        if self.battery_size == 70:
            range = 240
        elif self.battery_size == 85:
            range = 270


        message = "This car can go approximately " + str(range)
        message += " miles on full charge."
        print(messsage)
        
        
        
my_tesla.battery.get_range()
# Out:
#   File "<ipython-input-28-38bc8a8d11ce>", line 4
#     --snip--
#             ^
# SyntaxError: invalid syntax

# %%
## MODELING REAL WORLD OBJECTS 

# This requires a high level of thinking take car range for 
# example:
# does that have to do with battery or car type
# wehre do you include this?
# in the class Car but dependent on model and battery?

# don't be discouraged if you are ripping apart your classes 
# and rewriting them several times using

# %%
## TRY IT YOURSELF 9.6 - 9.9

class IceCreamStand(Restaurant):
    """Ice cream stand class, child of restaurant"""
    def __init__(self, restaurant_name, cuisine_type, flavors):
        """
        Initialize attributes of the parant calss.
        Then initalize attributes specific to an electric car
        """
        
        super().__init__(restaurant_name, cuisine_type)
        self.flavors = flavors
        
    def getIceDeets(self):
        """Prints details about an Ice Cream Stand"""
        print("rest name: " + self.restaurant_name +  
              "\nCuisine type: " + self.cuisine_type +
             "\nflavors: " + self.flavors)
        
        
ice_1 = IceCreamStand('Dairy queen', 'desert','vanilla, chocolate, blue moon')
print(ice_1.getIceDeets())




#########################################

class Admin(User):
    """Admin inherits from User"""
    def __init__(self, first_name, last_name, username, email, location):
        """
        Initialize attributes from parent (User)
        Then inialize unique to this class
        """
        super().__init__(first_name, last_name, username, email, location)
        self.privileges = []
        
    def show_privileges(self):
        """Display privilges for administrator"""
        print("\nPrivileges:")
        for privilege in self.privileges:
            print("-" + privilege)
            
            
eric = Admin('eric', 'matthes', 'e_matthes', 'e_mat@examp.com', 'alaska')
eric.describe_user()


eric.privileges = [
    'can reset passwords',
    'can moderate discussions',
    'can suspend accounts',
]
    
eric.show_privileges()    




#######################################################

class Privileges ():
    """A class to store an admin's privileges."""
    def __init__(self, privileges = []):
        self.priviliges = privileges
        
    def show_privileges(self):
        print("\nPrivileges: ")
        if self.privileges:
            for privilege in self.privileges:
                print("- " + privilege)
                
        else:
            print("- this user has no privileges.")
            
            
ang = Admin('eric', 'matthes', 'e_matthes', 'e_mat@examp.com', 'alaska')
ang.describe_user()
ang.show_privileges()  




########################################################################

class Car():
    """A simple attempt to represent a car."""

    def __init__(self, manufacturer, model, year):
        """Initialize attributes to describe a car."""
        self.manufacturer = manufacturer
        self.model = model
        self.year = year
        self.odometer_reading = 0
        
    def get_descriptive_name(self):
        """Return a neatly formatted descriptive name."""
        long_name = str(self.year) + ' ' + self.manufacturer + ' ' + self.model
        return long_name.title()
    
    def read_odometer(self):
        """Print a statement showing the car's mileage."""
        print("This car has " + str(self.odometer_reading) + " miles on it.")
        
    def update_odometer(self, mileage):
        """
        Set the odometer reading to the given value.
        Reject the change if it attempts to roll the odometer back.
        """
        if mileage >= self.odometer_reading:
            self.odometer_reading = mileage
        else:
            print("You can't roll back an odometer!")
    
    def increment_odometer(self, miles):
        """Add the given amount to the odometer reading."""
        self.odometer_reading += miles

class Battery():
    """A simple attempt to model a battery for an electric car."""

    def __init__(self, battery_size=60):
        """Initialize the batteery's attributes."""
        self.battery_size = battery_size

    def describe_battery(self):
        """Print a statement describing the battery size."""
        print("This car has a " + str(self.battery_size) + "-kWh battery.")

        
    def get_range(self):
        """Print a statement about the range this battery provides."""
        if self.battery_size == 60:
            range = 140
        elif self.battery_size == 85:
            range = 185
            
        message = "This car can go approximately " + str(range)
        message += " miles on a full charge."
        print(message)

    def upgrade_battery(self):
        """Upgrade the battery if possible."""
        if self.battery_size == 60:
            self.battery_size = 85
            print("Upgraded the battery to 85 kWh.")
        else:
            print("The battery is already upgraded.")
    
        
class ElectricCar(Car):
    """Models aspects of a car, specific to electric vehicles."""

    def __init__(self, manufacturer, model, year):
        """
        Initialize attributes of the parent class.
        Then initialize attributes specific to an electric car.
        """
        super().__init__(manufacturer, model, year)
        self.battery = Battery()


print("Make an electric car, and check the battery:")
my_tesla = ElectricCar('tesla', 'model s', 2016)
my_tesla.battery.describe_battery()

print("\nUpgrade the battery, and check it again:")
my_tesla.battery.upgrade_battery()
my_tesla.battery.describe_battery()

print("\nTry upgrading the battery a second time.")
my_tesla.battery.upgrade_battery()
my_tesla.battery.describe_battery()
# Out:
# rest name: Dairy queen
# Cuisine type: desert
# flavors: vanilla, chocolate, blue moon
# None
#
# First name: eric
# Last name: matthes
# Username: e_matthes
# email: e_mat@examp.com
# location: Alaska
#
# Privileges:
# -can reset passwords
# -can moderate discussions
# -can suspend accounts
#
# First name: eric
# Last name: matthes
# Username: e_matthes
# email: e_mat@examp.com
# location: Alaska
#
# Privileges:
# Make an electric car, and check the battery:
# This car has a 60-kWh battery.
#
# Upgrade the battery, and check it again:
# Upgraded the battery to 85 kWh.
# This car has a 85-kWh battery.
#
# Try upgrading the battery a second time.
# The battery is already upgraded.
# This car has a 85-kWh battery.

# %%
## IMPORTING CLASSES

# more functionality in classes = longer
# to help keep things uncluttered, you can  store calsses 
# in modules adn then import the classes you need into your 
# main program

# %%
## IMPORTING A SINGLE CLASS

# created car.py



from car import Car

my_new_car = Car('audi', 'a4', 2016)
print(my_new_car.get_descriptive_name())

my_new_car.odometer_reading = 23
my_new_car.read_odometer
# Out:
# 2016 Audi A4
# <bound method Car.read_odometer of <car.Car object at 0x00000274669508E0>>

# %%
## STORING / IMPORTIONG MULTIPLE CLASSES IN A MODULE

# you could have car and electric car in car.py

# so you could call
# from car import ElectricCar

# or
# from car import Car, ElectricCar

# %%
## IMPORTING AN ENTIRE MODULE

# You can import an entire module and then access the classes
# you need using dot notation. sipmle and easy to read code
#

# import car

# my_beetle = car.Car('Volkswagen', 'beetle', 2016)
# print(my_beetle)

# my_tesla = car.ElectricCar('tesla', 'roadster', 2016)
# print(my_tesla)

# %%
## IMPORTING ALL CLASSES FROM A MODULE

# from module_name import *

# this is not recommended for two reason, 
# not a clear sense of what classes a program uses
# adds confusion with names in a file

# %%
## IMPORTING A MODULE INTO A MODULE

# sometimes you'll want to spread out your classes
# over several modules to keep any one file from gowing too big
# and to avoid storing unrelated classes in teh same module

# when you sotre classes in several modules
# you may find that a class in one module depends on a class in another 
# import the recuired class into the first module


# for example store Car in one module and Electric car in a nother

# in electric_car.py
# from car import Car

# class battery

# class ElectricCar(Car)



# in car.py
#class Car

# in my_cars.py
# from car import Car
# from electric_car import ElectricCar


# and then define what you need 
# my_beetle = .........

# %%
## FINDING YOUR OWN WORKFLOW

# when first starting out write everything in one file and 
# once it's working move to classes

# %%
## TRY IT YOURSELF 9-10 9-11 

# in Restaurant.py and PCC Chapt 9 Restaurant

# in large_user.py and PCC Chapt 9 Large User

# I really can't do another one of these, I'm over chapt 9

# %%
## THE PYTHON STANDARD LIBRARY

# the standard library is a set of modules included 
# with every python installation

# OrderedDict is one of these classes you can import
# it keeps the order of info created in a dictionary

from collections import OrderedDict

favorite_languages = OrderedDict()

favorite_languages['jen'] = 'python'
favorite_languages['srah'] = 'c'
favorite_languages['ed'] = 'ruby'
favorite_languages['phil'] = 'python'

for name , language in favorite_languages.items():
    print(name.title() + "'s favorite language is " +
         language.title() + ".")
# Out:
# Jen's favorite language is Python.
# Srah's favorite language is C.
# Ed's favorite language is Ruby.
# Phil's favorite language is Python.

# %%
## TRY IT YOURSLEF 9.13 - 9.15

# not doing 9.13

from random import randint
x = randint(1,6)
print(x)


class Die():
    def __init__(self, sides):
        self.sides = sides
        
    def roll_die(self):
        return randint(1, self.sides)
    
    
d6 = Die(6)

results = []
for roll_num in range(10):
    result = d6.roll_die()
    results.append(result)
    
print("10 rolls of a 6-sided die:")
print(results)

# Make a 10 sided die, an dshow th eresults of 10 rolls.
d10 = Die(sides=10)

reults = []

for roll_num in range(10):
    result = d10.roll_die()
    results.append(result)
    
print("\n10 rolls of a 20-sided die:")
print(results)
# Out:
# 2
# 10 rolls of a 6-sided die:
# [5, 4, 5, 6, 6, 1, 1, 1, 2, 4]
#
# 10 rolls of a 20-sided die:
# [5, 4, 5, 6, 6, 1, 1, 1, 2, 4, 6, 2, 8, 3, 2, 8, 3, 1, 9, 6]
